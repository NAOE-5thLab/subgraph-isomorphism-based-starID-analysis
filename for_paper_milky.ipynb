# %%
import numpy as np
import pandas as pd
from utils import *

font_setting()
cmap = plt.get_cmap("ocean")
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
### probrem setting
# os
log_dir = "./log/matching/"
log_dir2 = "./log/obs_stars/"
seed = 100
# param
U = 1024
theta_FOV = 20

### compute params
seed_seq = np.random.SeedSequence(seed)
np_random = np.random.Generator(np.random.PCG64(seed_seq))
theta_res = np.arctan2(2 * np.tan(theta_FOV / 2), U)
epsilon = 2 * np.sqrt(2) * theta_res
theta_min = epsilon
theta_max = 2 * np.arctan(np.sqrt(2) * np.tan(theta_FOV / 2))

theta_FOV_list = [5, 10, 20, 40, 80]
M_lim_list = [3.5, 4.5, 5.5]
beta_list = [0.0, 0.2, 0.4, 0.6, 0.8]

# %%
border = np.pi/6

for flag in [True, False]:
    fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(4.8, 2.7), dpi=100)

    axes[1].set_xlabel("Angle of FOV : $\\theta_{\\mathrm{FOV}}$")
    axes[0].set_ylabel('Matching Probability')
    # axes[0].set_xlim(0, 80)
    axes[0].set_ylim(-0, 1)
    axes[0].set_xticks(range(len(theta_FOV_list))) 
    axes[0].set_xticklabels(theta_FOV_list)

    kwargs = {"ls": "dashed", "lw": 0.5}

    for ii, beta in enumerate(beta_list):
        for i, M_lim in enumerate(M_lim_list):
            ax = axes[i]
            ax.grid(visible=None, axis='x')
            p = []
            for j, theta_FOV in enumerate(theta_FOV_list):
                path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
                df = pd.read_csv(path)
                b = df["b_obs"].to_numpy()
                df = df[(-np.pi/6 < b)*(b < np.pi/6)==flag]
                prob = sum(df["unique"]*df["included"])/len(df)
                p.append(prob)
            kwargs.update({"color": cmap(ii/len(beta_list)), "label": "$\\beta=$"+f"${beta}$"})
            # 
            width = 0.95 * 1/len(beta_list)
            center = [N+(ii-int(len(beta_list)/2))*width for N in range(len(p))]
            ax.bar(center, p, align='center', width=width, **kwargs)
            # ax.plot([0]+theta_FOV_list, [0]+p, **kwargs)
            ax.set_title("$\\hat{M}_{\\mathrm{lim}}=$"+f"${M_lim}$")
        # ax.legend()

    lines_labels = [axes[0].get_legend_handles_labels()]
    lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
    lines = [lines[i] for i in [0,3,1,4,2]]
    labels = [labels[i] for i in [0,3,1,4,2]]
    fig.legend(lines, labels, bbox_to_anchor=(0.5, 1.06), loc="center", ncol=3)

    fig.tight_layout()
    fig.savefig(f"{log_dir}/matching_prob_bar_milky{flag}.pdf", bbox_inches='tight')

# %%
def get_hist(obs_stars_N):
    hist_count = np.zeros(10000)
    max_stars_n = 100
    for obs_stars_n in obs_stars_N:
        hist_count[obs_stars_n] += 1
        if max_stars_n < obs_stars_n:
            max_stars_n = obs_stars_n
    return hist_count[:max_stars_n+1]/len(obs_stars_N)

for flag in [True, False]:

    fig, axes = plt.subplots(3, 5, sharex=True, sharey=True, figsize=(4.8*2, 4), dpi=100)

    axes[2, 2].set_xlabel('Minimum number of stars in FOV : $N_{\\mathrm{min}}$')
    axes[1, 0].set_ylabel('Probability : $P \\ \\left(N_{\\mathrm{min}} \\leq N \\mid \\hat{M}_{\\mathrm{lim}},\\ \\beta,\\ \\theta_{\\mathrm{FOV}}\\right)$')
    # axes[2, 2].set_xlabel('Number of stars in FOV : $N$')
    # axes[1, 0].set_ylabel('Probability : $P \\ \\left(N \\mid \\hat{M}_{\\mathrm{lim}},\\ \\beta,\\ \\theta_{\\mathrm{FOV}}\\right)$')
    axes[0, 0].set_xlim(-0.5, 10.5)
    axes[0, 0].set_ylim(0.0, 1.0)
    # axes[0, 0].set_ylim(1e-4, 1e0)
    # axes[0, 0].set_yscale("log")
    axes[0, 0].set_xticks(list(range(0, 11))) 
    axes[0, 0].set_xticklabels(list(range(0, 11)))
    # axes[0, 0].set_yticks([1e-4,1e-3,1e-2,1e-1,1e0]) 

    markers = ["o", "v", "^", "<", ">"]
    colors = [cmap(0/6), cmap(2/6), cmap(3/6), cmap(4/6), cmap(5/6)]
    kwargs = {"ls": "dashed", "lw": 0.5}

    M_lim = 3.5
    for ii, beta in enumerate(beta_list):
        ax = axes[0, ii]
        ax.grid(visible=None, axis='x')
        for i, theta_FOV in enumerate(theta_FOV_list):
            kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
            path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
            print(path)
            df = pd.read_csv(path)
            b = df["b_obs"].to_numpy()
            df = df[(-np.pi/6 < b)*(b < np.pi/6)==flag]
            pN = get_hist(df["N_obs"].to_numpy())
            pN_cum = [sum(pN[i:]) for i in range(len(pN))]
            width = 0.95 * 1/len(theta_FOV_list)
            center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(pN))]
            ax.bar(center, pN_cum, align='center', width=width, **kwargs)
        # ax.legend()
        ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

    M_lim = 4.5
    for ii, beta in enumerate(beta_list):
        ax = axes[1, ii]
        ax.grid(visible=None, axis='x')
        for i, theta_FOV in enumerate(theta_FOV_list):
            kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
            path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
            print(path)
            df = pd.read_csv(path)
            b = df["b_obs"].to_numpy()
            df = df[(-np.pi/6 < b)*(b < np.pi/6)==flag]
            pN = get_hist(df["N_obs"].to_numpy())
            pN_cum = [sum(pN[i:]) for i in range(len(pN))]
            width = 0.95 * 1/len(theta_FOV_list)
            center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(pN))]
            ax.bar(center, pN_cum, align='center', width=width, **kwargs)
        # ax.legend()
        ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

    M_lim = 5.5
    for ii, beta in enumerate(beta_list):
        ax = axes[2, ii]
        ax.grid(visible=None, axis='x')
        for i, theta_FOV in enumerate(theta_FOV_list):
            kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
            path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
            print(path)
            df = pd.read_csv(path)
            b = df["b_obs"].to_numpy()
            df = df[(-np.pi/6 < b)*(b < np.pi/6)==flag]
            pN = get_hist(df["N_obs"].to_numpy())
            pN_cum = [sum(pN[i:]) for i in range(len(pN))]
            width = 0.95 * 1/len(theta_FOV_list)
            center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(pN))]
            ax.bar(center, pN_cum, align='center', width=width, **kwargs)
        # ax.legend()
        ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

    lines_labels = [axes[0, 0].get_legend_handles_labels()]
    lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
    fig.legend(lines, labels, bbox_to_anchor=(0.5, 1.01), loc="center", ncol=5)

    fig.tight_layout()
    fig.savefig(f"{log_dir}/obs_cum_distribution_bar_milky{flag}.pdf", bbox_inches='tight')
# Out:
# ./log/matching//matching_FOV5_M3.5_beta0.0.dat
# ./log/matching//matching_FOV10_M3.5_beta0.0.dat
# ./log/matching//matching_FOV20_M3.5_beta0.0.dat
# ./log/matching//matching_FOV40_M3.5_beta0.0.dat
# ./log/matching//matching_FOV80_M3.5_beta0.0.dat
# ./log/matching//matching_FOV5_M3.5_beta0.2.dat
# ./log/matching//matching_FOV10_M3.5_beta0.2.dat
# ./log/matching//matching_FOV20_M3.5_beta0.2.dat
# ./log/matching//matching_FOV40_M3.5_beta0.2.dat
# ./log/matching//matching_FOV80_M3.5_beta0.2.dat
# ./log/matching//matching_FOV5_M3.5_beta0.4.dat
# ./log/matching//matching_FOV10_M3.5_beta0.4.dat
# ./log/matching//matching_FOV20_M3.5_beta0.4.dat
# ./log/matching//matching_FOV40_M3.5_beta0.4.dat
# ./log/matching//matching_FOV80_M3.5_beta0.4.dat
# ./log/matching//matching_FOV5_M3.5_beta0.6.dat
# ./log/matching//matching_FOV10_M3.5_beta0.6.dat
# ./log/matching//matching_FOV20_M3.5_beta0.6.dat
# ./log/matching//matching_FOV40_M3.5_beta0.6.dat
# ./log/matching//matching_FOV80_M3.5_beta0.6.dat
# ./log/matching//matching_FOV5_M3.5_beta0.8.dat
# ./log/matching//matching_FOV10_M3.5_beta0.8.dat
# ./log/matching//matching_FOV20_M3.5_beta0.8.dat
# ./log/matching//matching_FOV40_M3.5_beta0.8.dat
# ./log/matching//matching_FOV80_M3.5_beta0.8.dat
# ./log/matching//matching_FOV5_M4.5_beta0.0.dat
# ./log/matching//matching_FOV10_M4.5_beta0.0.dat
# ./log/matching//matching_FOV20_M4.5_beta0.0.dat
# ./log/matching//matching_FOV40_M4.5_beta0.0.dat
# ./log/matching//matching_FOV80_M4.5_beta0.0.dat
# ./log/matching//matching_FOV5_M4.5_beta0.2.dat
# ./log/matching//matching_FOV10_M4.5_beta0.2.dat
# ./log/matching//matching_FOV20_M4.5_beta0.2.dat
# ./log/matching//matching_FOV40_M4.5_beta0.2.dat
# ./log/matching//matching_FOV80_M4.5_beta0.2.dat
# ./log/matching//matching_FOV5_M4.5_beta0.4.dat
# ./log/matching//matching_FOV10_M4.5_beta0.4.dat
# ./log/matching//matching_FOV20_M4.5_beta0.4.dat
# ./log/matching//matching_FOV40_M4.5_beta0.4.dat
# ./log/matching//matching_FOV80_M4.5_beta0.4.dat
# ./log/matching//matching_FOV5_M4.5_beta0.6.dat
# ./log/matching//matching_FOV10_M4.5_beta0.6.dat
# ./log/matching//matching_FOV20_M4.5_beta0.6.dat
# ./log/matching//matching_FOV40_M4.5_beta0.6.dat
# ./log/matching//matching_FOV80_M4.5_beta0.6.dat
# ./log/matching//matching_FOV5_M4.5_beta0.8.dat
# ./log/matching//matching_FOV10_M4.5_beta0.8.dat
# ./log/matching//matching_FOV20_M4.5_beta0.8.dat
# ./log/matching//matching_FOV40_M4.5_beta0.8.dat
# ./log/matching//matching_FOV80_M4.5_beta0.8.dat
# ./log/matching//matching_FOV5_M5.5_beta0.0.dat
# ./log/matching//matching_FOV10_M5.5_beta0.0.dat
# ./log/matching//matching_FOV20_M5.5_beta0.0.dat
# ./log/matching//matching_FOV40_M5.5_beta0.0.dat
# ./log/matching//matching_FOV80_M5.5_beta0.0.dat
# ./log/matching//matching_FOV5_M5.5_beta0.2.dat
# ./log/matching//matching_FOV10_M5.5_beta0.2.dat
# ./log/matching//matching_FOV20_M5.5_beta0.2.dat
# ./log/matching//matching_FOV40_M5.5_beta0.2.dat
# ./log/matching//matching_FOV80_M5.5_beta0.2.dat
# ./log/matching//matching_FOV5_M5.5_beta0.4.dat
# ./log/matching//matching_FOV10_M5.5_beta0.4.dat
# ./log/matching//matching_FOV20_M5.5_beta0.4.dat
# ./log/matching//matching_FOV40_M5.5_beta0.4.dat
# ./log/matching//matching_FOV80_M5.5_beta0.4.dat
# ./log/matching//matching_FOV5_M5.5_beta0.6.dat
# ./log/matching//matching_FOV10_M5.5_beta0.6.dat
# ./log/matching//matching_FOV20_M5.5_beta0.6.dat
# ./log/matching//matching_FOV40_M5.5_beta0.6.dat
# ./log/matching//matching_FOV80_M5.5_beta0.6.dat
# ./log/matching//matching_FOV5_M5.5_beta0.8.dat
# ./log/matching//matching_FOV10_M5.5_beta0.8.dat
# ./log/matching//matching_FOV20_M5.5_beta0.8.dat
# ./log/matching//matching_FOV40_M5.5_beta0.8.dat
# ./log/matching//matching_FOV80_M5.5_beta0.8.dat
# ./log/matching//matching_FOV5_M3.5_beta0.0.dat
# ./log/matching//matching_FOV10_M3.5_beta0.0.dat
# ./log/matching//matching_FOV20_M3.5_beta0.0.dat
# ./log/matching//matching_FOV40_M3.5_beta0.0.dat
# ./log/matching//matching_FOV80_M3.5_beta0.0.dat
# ./log/matching//matching_FOV5_M3.5_beta0.2.dat
# ./log/matching//matching_FOV10_M3.5_beta0.2.dat
# ./log/matching//matching_FOV20_M3.5_beta0.2.dat
# ./log/matching//matching_FOV40_M3.5_beta0.2.dat
# ./log/matching//matching_FOV80_M3.5_beta0.2.dat
# ./log/matching//matching_FOV5_M3.5_beta0.4.dat
# ./log/matching//matching_FOV10_M3.5_beta0.4.dat
# ./log/matching//matching_FOV20_M3.5_beta0.4.dat
# ./log/matching//matching_FOV40_M3.5_beta0.4.dat
# ./log/matching//matching_FOV80_M3.5_beta0.4.dat
# ./log/matching//matching_FOV5_M3.5_beta0.6.dat
# ./log/matching//matching_FOV10_M3.5_beta0.6.dat
# ./log/matching//matching_FOV20_M3.5_beta0.6.dat
# ./log/matching//matching_FOV40_M3.5_beta0.6.dat
# ./log/matching//matching_FOV80_M3.5_beta0.6.dat
# ./log/matching//matching_FOV5_M3.5_beta0.8.dat
# ./log/matching//matching_FOV10_M3.5_beta0.8.dat
# ./log/matching//matching_FOV20_M3.5_beta0.8.dat
# ./log/matching//matching_FOV40_M3.5_beta0.8.dat
# ./log/matching//matching_FOV80_M3.5_beta0.8.dat
# ./log/matching//matching_FOV5_M4.5_beta0.0.dat
# ./log/matching//matching_FOV10_M4.5_beta0.0.dat
# ./log/matching//matching_FOV20_M4.5_beta0.0.dat
# ./log/matching//matching_FOV40_M4.5_beta0.0.dat
# ./log/matching//matching_FOV80_M4.5_beta0.0.dat
# ./log/matching//matching_FOV5_M4.5_beta0.2.dat
# ./log/matching//matching_FOV10_M4.5_beta0.2.dat
# ./log/matching//matching_FOV20_M4.5_beta0.2.dat
# ./log/matching//matching_FOV40_M4.5_beta0.2.dat
# ./log/matching//matching_FOV80_M4.5_beta0.2.dat
# ./log/matching//matching_FOV5_M4.5_beta0.4.dat
# ./log/matching//matching_FOV10_M4.5_beta0.4.dat
# ./log/matching//matching_FOV20_M4.5_beta0.4.dat
# ./log/matching//matching_FOV40_M4.5_beta0.4.dat
# ./log/matching//matching_FOV80_M4.5_beta0.4.dat
# ./log/matching//matching_FOV5_M4.5_beta0.6.dat
# ./log/matching//matching_FOV10_M4.5_beta0.6.dat
# ./log/matching//matching_FOV20_M4.5_beta0.6.dat
# ./log/matching//matching_FOV40_M4.5_beta0.6.dat
# ./log/matching//matching_FOV80_M4.5_beta0.6.dat
# ./log/matching//matching_FOV5_M4.5_beta0.8.dat
# ./log/matching//matching_FOV10_M4.5_beta0.8.dat
# ./log/matching//matching_FOV20_M4.5_beta0.8.dat
# ./log/matching//matching_FOV40_M4.5_beta0.8.dat
# ./log/matching//matching_FOV80_M4.5_beta0.8.dat
# ./log/matching//matching_FOV5_M5.5_beta0.0.dat
# ./log/matching//matching_FOV10_M5.5_beta0.0.dat
# ./log/matching//matching_FOV20_M5.5_beta0.0.dat
# ./log/matching//matching_FOV40_M5.5_beta0.0.dat
# ./log/matching//matching_FOV80_M5.5_beta0.0.dat
# ./log/matching//matching_FOV5_M5.5_beta0.2.dat
# ./log/matching//matching_FOV10_M5.5_beta0.2.dat
# ./log/matching//matching_FOV20_M5.5_beta0.2.dat
# ./log/matching//matching_FOV40_M5.5_beta0.2.dat
# ./log/matching//matching_FOV80_M5.5_beta0.2.dat
# ./log/matching//matching_FOV5_M5.5_beta0.4.dat
# ./log/matching//matching_FOV10_M5.5_beta0.4.dat
# ./log/matching//matching_FOV20_M5.5_beta0.4.dat
# ./log/matching//matching_FOV40_M5.5_beta0.4.dat
# ./log/matching//matching_FOV80_M5.5_beta0.4.dat
# ./log/matching//matching_FOV5_M5.5_beta0.6.dat
# ./log/matching//matching_FOV10_M5.5_beta0.6.dat
# ./log/matching//matching_FOV20_M5.5_beta0.6.dat
# ./log/matching//matching_FOV40_M5.5_beta0.6.dat
# ./log/matching//matching_FOV80_M5.5_beta0.6.dat
# ./log/matching//matching_FOV5_M5.5_beta0.8.dat
# ./log/matching//matching_FOV10_M5.5_beta0.8.dat
# ./log/matching//matching_FOV20_M5.5_beta0.8.dat
# ./log/matching//matching_FOV40_M5.5_beta0.8.dat
# ./log/matching//matching_FOV80_M5.5_beta0.8.dat

# %%
for flag in [True, False]:

    fig, axes = plt.subplots(3, 5, sharex=True, sharey=True, figsize=(4.8*2, 4), dpi=100)

    axes[2, 2].set_xlabel('Number of stars required for unique matching : $p_{\\mathrm{match}}$')
    axes[1, 0].set_ylabel('Probability : $P \\ \\left(p_{\mathrm{match}} \\mid \\hat{M}_{\\mathrm{lim}},\\ \\beta,\\ \\theta_{\\mathrm{FOV}}\\right)$')
    axes[0, 0].set_xlim(-0.5, 10.5)
    axes[0, 0].set_ylim(1e-4, 1e0)
    axes[0, 0].set_yscale("log")
    axes[0, 0].set_xticks(list(range(0, 11))) 
    axes[0, 0].set_xticklabels(list(range(0, 11)))
    axes[0, 0].set_yticks([1e-4,1e-3,1e-2,1e-1,1e0]) 

    markers = ["o", "v", "^", "<", ">"]
    colors = [cmap(0/6), cmap(2/6), cmap(3/6), cmap(4/6), cmap(5/6)]
    kwargs = {"ls": "dashed", "lw": 0.5}

    M_lim = 3.5
    for ii, beta in enumerate(beta_list):
        ax = axes[0, ii]
        ax.grid(visible=None, axis='x')
        for i, theta_FOV in enumerate(theta_FOV_list):
            kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
            path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
            print(path)
            df = pd.read_csv(path)
            b = df["b_obs"].to_numpy()
            df = df[(-np.pi/6 < b)*(b < np.pi/6)==flag]
            df["match"] = df["unique"]*df["included"]
            df_N_match = df.loc[df["match"], "N_match"]
            # 
            hists = [0]*300
            for N_match in df_N_match:
                hists[N_match] += 1
            dens = []
            for hist in hists:
                den = 0 if len(df_N_match)==0 else hist/(len(df_N_match))
                dens.append(den)
            width = 0.95 * 1/len(theta_FOV_list)
            center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(dens))]
            ax.bar(center, dens, align='center', width=width, **kwargs)
        # ax.legend()
        ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

    M_lim = 4.5
    for ii, beta in enumerate(beta_list):
        ax = axes[1, ii]
        ax.grid(visible=None, axis='x')
        for i, theta_FOV in enumerate(theta_FOV_list):
            kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
            path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
            df = pd.read_csv(path)
            b = df["b_obs"].to_numpy()
            df = df[(-np.pi/6 < b)*(b < np.pi/6)==flag]
            df["match"] = df["unique"]*df["included"]
            df_N_match = df.loc[df["match"], "N_match"]
            # 
            hists = [0]*300
            for N_match in df_N_match:
                hists[N_match] += 1
            dens = []
            for hist in hists:
                den = 0 if len(df_N_match)==0 else hist/(len(df_N_match))
                dens.append(den)
            width = 0.95 * 1/len(theta_FOV_list)
            center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(dens))]
            ax.bar(center, dens, align='center', width=width, **kwargs)
        # ax.legend()
        ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

    M_lim = 5.5
    for ii, beta in enumerate(beta_list):
        ax = axes[2, ii]
        ax.grid(visible=None, axis='x')
        for i, theta_FOV in enumerate(theta_FOV_list):
            kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
            path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
            df = pd.read_csv(path)
            b = df["b_obs"].to_numpy()
            df = df[(-np.pi/6 < b)*(b < np.pi/6)==flag]
            df["match"] = df["unique"]*df["included"]
            df_N_match = df.loc[df["match"], "N_match"]
            # 
            hists = [0]*300
            for N_match in df_N_match:
                hists[N_match] += 1
            dens = []
            for hist in hists:
                den = 0 if len(df_N_match)==0 else hist/(len(df_N_match))
                dens.append(den)
            width = 0.95 * 1/len(theta_FOV_list)
            center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(dens))]
            ax.bar(center, dens, align='center', width=width, **kwargs)
        # ax.legend()
        ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

    lines_labels = [axes[0, 0].get_legend_handles_labels()]
    lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
    fig.legend(lines, labels, bbox_to_anchor=(0.5, 1.01), loc="center", ncol=5)

    fig.tight_layout()
    fig.savefig(f"{log_dir}/required_distribution_bar_milky{flag}.pdf", bbox_inches='tight')
# Out:
# ./log/matching//matching_FOV5_M3.5_beta0.0.dat
# ./log/matching//matching_FOV10_M3.5_beta0.0.dat
# ./log/matching//matching_FOV20_M3.5_beta0.0.dat
# ./log/matching//matching_FOV40_M3.5_beta0.0.dat
# ./log/matching//matching_FOV80_M3.5_beta0.0.dat
# ./log/matching//matching_FOV5_M3.5_beta0.2.dat
# ./log/matching//matching_FOV10_M3.5_beta0.2.dat
# ./log/matching//matching_FOV20_M3.5_beta0.2.dat
# ./log/matching//matching_FOV40_M3.5_beta0.2.dat
# ./log/matching//matching_FOV80_M3.5_beta0.2.dat
# ./log/matching//matching_FOV5_M3.5_beta0.4.dat
# ./log/matching//matching_FOV10_M3.5_beta0.4.dat
# ./log/matching//matching_FOV20_M3.5_beta0.4.dat
# ./log/matching//matching_FOV40_M3.5_beta0.4.dat
# ./log/matching//matching_FOV80_M3.5_beta0.4.dat
# ./log/matching//matching_FOV5_M3.5_beta0.6.dat
# ./log/matching//matching_FOV10_M3.5_beta0.6.dat
# ./log/matching//matching_FOV20_M3.5_beta0.6.dat
# ./log/matching//matching_FOV40_M3.5_beta0.6.dat
# ./log/matching//matching_FOV80_M3.5_beta0.6.dat
# ./log/matching//matching_FOV5_M3.5_beta0.8.dat
# ./log/matching//matching_FOV10_M3.5_beta0.8.dat
# ./log/matching//matching_FOV20_M3.5_beta0.8.dat
# ./log/matching//matching_FOV40_M3.5_beta0.8.dat
# ./log/matching//matching_FOV80_M3.5_beta0.8.dat
# ./log/matching//matching_FOV5_M3.5_beta0.0.dat
# ./log/matching//matching_FOV10_M3.5_beta0.0.dat
# ./log/matching//matching_FOV20_M3.5_beta0.0.dat
# ./log/matching//matching_FOV40_M3.5_beta0.0.dat
# ./log/matching//matching_FOV80_M3.5_beta0.0.dat
# ./log/matching//matching_FOV5_M3.5_beta0.2.dat
# ./log/matching//matching_FOV10_M3.5_beta0.2.dat
# ./log/matching//matching_FOV20_M3.5_beta0.2.dat
# ./log/matching//matching_FOV40_M3.5_beta0.2.dat
# ./log/matching//matching_FOV80_M3.5_beta0.2.dat
# ./log/matching//matching_FOV5_M3.5_beta0.4.dat
# ./log/matching//matching_FOV10_M3.5_beta0.4.dat
# ./log/matching//matching_FOV20_M3.5_beta0.4.dat
# ./log/matching//matching_FOV40_M3.5_beta0.4.dat
# ./log/matching//matching_FOV80_M3.5_beta0.4.dat
# ./log/matching//matching_FOV5_M3.5_beta0.6.dat
# ./log/matching//matching_FOV10_M3.5_beta0.6.dat
# ./log/matching//matching_FOV20_M3.5_beta0.6.dat
# ./log/matching//matching_FOV40_M3.5_beta0.6.dat
# ./log/matching//matching_FOV80_M3.5_beta0.6.dat
# ./log/matching//matching_FOV5_M3.5_beta0.8.dat
# ./log/matching//matching_FOV10_M3.5_beta0.8.dat
# ./log/matching//matching_FOV20_M3.5_beta0.8.dat
# ./log/matching//matching_FOV40_M3.5_beta0.8.dat
# ./log/matching//matching_FOV80_M3.5_beta0.8.dat

# %%
fig, axes = plt.subplots(3, 5, sharex=True, sharey=True, figsize=(4.8*2, 4), dpi=100)

axes[2, 2].set_xlabel('Number of stars required for unique matching : $p_{\\mathrm{match}}$')
axes[1, 0].set_ylabel('Probability : $P \\ \\left(p_{\mathrm{match}} \\mid \\hat{M}_{\\mathrm{lim}},\\ \\beta,\\ \\theta_{\\mathrm{FOV}}\\right)$')
axes[0, 0].set_xlim(-0.5, 10.5)
axes[0, 0].set_ylim(1e-4, 1e0)
axes[0, 0].set_yscale("log")
axes[0, 0].set_xticks(list(range(0, 11))) 
axes[0, 0].set_xticklabels(list(range(0, 11)))
axes[0, 0].set_yticks([1e-4,1e-3,1e-2,1e-1,1e0]) 

markers = ["o", "v", "^", "<", ">"]
colors = [cmap(0/6), cmap(2/6), cmap(3/6), cmap(4/6), cmap(5/6)]
kwargs = {"ls": "dashed", "lw": 0.5}

M_lim = 3.5
for ii, beta in enumerate(beta_list):
    ax = axes[0, ii]
    ax.grid(visible=None, axis='x')
    for i, theta_FOV in enumerate(theta_FOV_list):
        kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
        path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
        print(path)
        df = pd.read_csv(path)
        df["match"] = df["unique"]*df["included"]
        df_N_match = df.loc[df["match"], "N_match"]
        # 
        hists = [0]*300
        for N_match in df_N_match:
            hists[N_match] += 1
        dens = []
        for hist in hists:
            den = 0 if len(df_N_match)==0 else hist/(len(df_N_match))
            dens.append(den)
        width = 0.95 * 1/len(theta_FOV_list)
        center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(dens))]
        ax.bar(center, dens, align='center', width=width, **kwargs)
    # ax.legend()
    ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

M_lim = 4.5
for ii, beta in enumerate(beta_list):
    ax = axes[1, ii]
    ax.grid(visible=None, axis='x')
    for i, theta_FOV in enumerate(theta_FOV_list):
        kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
        path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
        df = pd.read_csv(path)
        df["match"] = df["unique"]*df["included"]
        df_N_match = df.loc[df["match"], "N_match"]
        # 
        hists = [0]*300
        for N_match in df_N_match:
            hists[N_match] += 1
        dens = []
        for hist in hists:
            den = 0 if len(df_N_match)==0 else hist/(len(df_N_match))
            dens.append(den)
        width = 0.95 * 1/len(theta_FOV_list)
        center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(dens))]
        ax.bar(center, dens, align='center', width=width, **kwargs)
    # ax.legend()
    ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

M_lim = 5.5
for ii, beta in enumerate(beta_list):
    ax = axes[2, ii]
    ax.grid(visible=None, axis='x')
    for i, theta_FOV in enumerate(theta_FOV_list):
        kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
        path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
        df = pd.read_csv(path)
        df["match"] = df["unique"]*df["included"]
        df_N_match = df.loc[df["match"], "N_match"]
        # 
        hists = [0]*300
        for N_match in df_N_match:
            hists[N_match] += 1
        dens = []
        for hist in hists:
            den = 0 if len(df_N_match)==0 else hist/(len(df_N_match))
            dens.append(den)
        width = 0.95 * 1/len(theta_FOV_list)
        center = [N+(i-int(len(theta_FOV_list)/2))*width for N in range(len(dens))]
        ax.bar(center, dens, align='center', width=width, **kwargs)
    # ax.legend()
    ax.set_title("$M_{\\mathrm{lim}}=$"+f"${M_lim}$" + ", $\\beta=$"+f"${beta}$")

lines_labels = [axes[0, 0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
fig.legend(lines, labels, bbox_to_anchor=(0.5, 1.01), loc="center", ncol=5)

fig.tight_layout()
fig.savefig(f"{log_dir}/required_distribution_bar.pdf", bbox_inches='tight')
# Out:
# ./log/matching//matching_FOV5_M3.5_beta0.0.dat
# ./log/matching//matching_FOV10_M3.5_beta0.0.dat
# ./log/matching//matching_FOV20_M3.5_beta0.0.dat
# ./log/matching//matching_FOV40_M3.5_beta0.0.dat
# ./log/matching//matching_FOV80_M3.5_beta0.0.dat
# ./log/matching//matching_FOV5_M3.5_beta0.2.dat
# ./log/matching//matching_FOV10_M3.5_beta0.2.dat
# ./log/matching//matching_FOV20_M3.5_beta0.2.dat
# ./log/matching//matching_FOV40_M3.5_beta0.2.dat
# ./log/matching//matching_FOV80_M3.5_beta0.2.dat
# ./log/matching//matching_FOV5_M3.5_beta0.4.dat
# ./log/matching//matching_FOV10_M3.5_beta0.4.dat
# ./log/matching//matching_FOV20_M3.5_beta0.4.dat
# ./log/matching//matching_FOV40_M3.5_beta0.4.dat
# ./log/matching//matching_FOV80_M3.5_beta0.4.dat
# ./log/matching//matching_FOV5_M3.5_beta0.6.dat
# ./log/matching//matching_FOV10_M3.5_beta0.6.dat
# ./log/matching//matching_FOV20_M3.5_beta0.6.dat
# ./log/matching//matching_FOV40_M3.5_beta0.6.dat
# ./log/matching//matching_FOV80_M3.5_beta0.6.dat
# ./log/matching//matching_FOV5_M3.5_beta0.8.dat
# ./log/matching//matching_FOV10_M3.5_beta0.8.dat
# ./log/matching//matching_FOV20_M3.5_beta0.8.dat
# ./log/matching//matching_FOV40_M3.5_beta0.8.dat
# ./log/matching//matching_FOV80_M3.5_beta0.8.dat

# %%
fig, axes = plt.subplots(1, 3, sharex=True, sharey=True, figsize=(4.8, 2.7), dpi=100)

axes[1].set_xlabel("Angle of FOV : $\\theta_{\\mathrm{FOV}}$")
axes[0].set_ylabel('Expected value of number\nof stars: $E [p_{\\mathrm{match}}]$')
# axes[0].set_xlim(0, 80)
# axes[0].set_ylim(-0, 1)
axes[0].set_xticks(range(len(theta_FOV_list))) 
axes[0].set_xticklabels(theta_FOV_list)

kwargs = {"ls": "dashed", "lw": 0.5}

for ii, beta in enumerate(beta_list):
    for i, M_lim in enumerate(M_lim_list):
        ax = axes[i]
        ax.grid(visible=None, axis='x')
        e = []
        for j, theta_FOV in enumerate(theta_FOV_list):
            # kwargs.update({"color": colors[i], "label": "$\\theta_{\\mathrm{FOV}}=$"+f"${theta_FOV}$"+"$\\ \\mathrm{(deg.)}$"})
            path = f"{log_dir}/matching_FOV{theta_FOV}_M{M_lim}_beta{beta}.dat"
            df = pd.read_csv(path)
            df["match"] = df["unique"]*df["included"]
            df_N_match = df.loc[df["match"], "N_match"]
            # 
            hists = [0]*300
            for N_match in df_N_match:
                hists[N_match] += 1
            dens = []
            for hist in hists:
                den = 0 if len(df_N_match)==0 else hist/(len(df_N_match))
                dens.append(den)
            expected = sum([i*den for i, den in enumerate(dens)])
            e.append(expected)
        kwargs.update({"color": cmap(ii/len(beta_list)), "label": "$\\beta=$"+f"${beta}$"})
        # 
        width = 0.95 * 1/len(beta_list)
        center = [N+(ii-int(len(beta_list)/2))*width for N in range(len(e))]
        ax.bar(center, e, align='center', width=width, **kwargs)
        # ax.plot([0]+theta_FOV_list, [0]+p, **kwargs)
        ax.set_title("$\\hat{M}_{\\mathrm{lim}}=$"+f"${M_lim}$")
    # ax.legend()

lines_labels = [axes[0].get_legend_handles_labels()]
lines, labels = [sum(lol, []) for lol in zip(*lines_labels)]
lines = [lines[i] for i in [0,3,1,4,2]]
labels = [labels[i] for i in [0,3,1,4,2]]
fig.legend(lines, labels, bbox_to_anchor=(0.5, 1.06), loc="center", ncol=3)

fig.tight_layout()
fig.savefig(f"{log_dir}/expected_required_bar.pdf", bbox_inches='tight')
